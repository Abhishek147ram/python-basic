# %%
import pandas as pd

df = pd.read_csv('healthcare_lifestyle_dataset.csv')
df.head()
# Out:
#     Age  Gender  Height_cm  Weight_kg   BMI Marital_Status     Occupation  \
# 0  56.0   Other      173.0       70.0  25.5       Divorced  Self-Employed
# 1  46.0    Male      146.0       61.0  21.4       Divorced            NaN
# 2  32.0  Female      178.0       84.0  28.1       Divorced  Self-Employed
# 3  60.0  Female      171.0        NaN   NaN         Single        Student
# 4  25.0    Male      183.0       79.0   NaN       Divorced     Unemployed
#
#    Work_Hours_Per_Week  Daily_Steps Exercise_Frequency  ...  \
# 0                  0.0       9373.0                NaN  ...
# 1                 61.0      17281.0              Daily  ...
# 2                  8.0          NaN               Rare  ...
# 3                 40.0      18350.0             Weekly  ...
# 4                  NaN        940.0                NaN  ...
#
#    Chronic_Stress_Days_Per_Month Social_Interaction_Level Meditation_Habit  \
# 0                           23.0                      NaN               No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            9000 non-null   float64
#  1   Gender                         9000 non-null   object
#  2   Height_cm                      9000 non-null   float64
#  3   Weight_kg                      9000 non-null   float64
#  4   BMI                            9000 non-null   float64
#  5   Marital_Status                 9000 non-null   object
#  6   Occupation                     9000 non-null   object
#  7   Work_Hours_Per_Week            9000 non-null   float64
#  8   Daily_Steps                    9000 non-null   float64
#  9   Exercise_Frequency             6692 non-null   object
#  10  Sleep_Hours                    9000 non-null   float64
#  11  Sleep_Quality                  9000 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age    Height_cm    Weight_kg          BMI  \
# count  9000.000000  9000.000000  9000.000000  9000.000000
# mean     41.095222   166.871333    77.182778    26.413411
# std      13.445760    12.900575    18.700458     4.895016
# min      18.000000   145.000000    45.000000    18.000000
# 25%      30.000000   156.000000    61.000000    22.200000
# 50%      41.000000   167.000000    77.000000    26.400000
# 75%      53.000000   178.000000    93.000000    30.600000
# max      64.000000   189.000000   109.000000    35.000000
#
#        Work_Hours_Per_Week   Daily_Steps  Sleep_Hours  Screen_Time_Hours  \
# count          9000.000000   9000.000000  9000.000000        9000.000000
# mean             33.942444  10298.947667     6.022556           6.502678
# std              20.160816   5618.753052     1.727003           3.155030
# min               0.000000    501.000000     3.000000           1.000000
# 25%              17.000000   5501.750000     4.500000           3.800000
# ...

# %%
df.isnull().sum()
# Out:
# Age                              1000
# Gender                           1000
# Height_cm                        1000
# Weight_kg                        1000
# BMI                              1000
# Marital_Status                   1000
# Occupation                       1000
# Work_Hours_Per_Week              1000
# Daily_Steps                      1000
# Exercise_Frequency               3308
# Sleep_Hours                      1000
# Sleep_Quality                    1000
# Stress_Level                     1000
# Screen_Time_Hours                1000
# Water_Intake_Liters              1000
# Caffeine_Intake                  3252
# Smoking_Habit                    1000
# Alcohol_Consumption              4020
# Diet_Type                        1000
# Junk_Food_Frequency              1000
# Mental_Wellbeing_Score           1000
# Physical_Activity_Level          1000
# Heart_Rate_Resting               1000
# Blood_Pressure_Category          1000
# Chronic_Stress_Days_Per_Month    1000
# ...

# %%
def categorize_wellness_score(score):
    if score <= 4:
        return 'Low'
    elif 4 < score <= 7:
        return 'Medium'
    else:
        return 'High'

# %%
df['Wellness_Score_Category'] = df['Happiness_Score'].apply(categorize_wellness_score)

# %%
numerical_cols = ['Age', 'Height_cm', 'Weight_kg', 'BMI', 'Work_Hours_Per_Week', 'Daily_Steps',
                  'Sleep_Hours', 'Screen_Time_Hours', 'Water_Intake_Liters', 'Mental_Wellbeing_Score',
                  'Heart_Rate_Resting', 'Chronic_Stress_Days_Per_Month', 'Outdoor_Activity_Hours', 'Happiness_Score']

# %%
categorical_cols = ['Gender', 'Marital_Status', 'Occupation', 'Exercise_Frequency', 'Sleep_Quality',
                    'Stress_Level', 'Caffeine_Intake', 'Smoking_Habit', 'Alcohol_Consumption', 'Diet_Type',
                    'Junk_Food_Frequency', 'Physical_Activity_Level', 'Blood_Pressure_Category',
                    'Social_Interaction_Level', 'Meditation_Habit', 'Work_Life_Balance', 'Healthcare_Access',
                    'Health_App_Usage', 'Awareness_of_Mental_Health', 'City_Type']

# %%
numerical_cols = [col for col in numerical_cols if col in df.columns]

# %%
categorical_cols = [col for col in categorical_cols if col in df.columns]

# %%
for col in numerical_cols:
    if df[col].isnull().any():
        median_val = df[col].median()
        df[col].fillna(median_val, inplace=True)
# Out:
# C:\Users\WIN 11 PRO\AppData\Local\Temp\ipykernel_12656\1768228671.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_val, inplace=True)
# C:\Users\WIN 11 PRO\AppData\Local\Temp\ipykernel_12656\1768228671.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
for col in categorical_cols:
    if df[col].isnull().any():
        mode_val = df[col].mode()[0]
        df[col].fillna(mode_val, inplace=True)
# Out:
# C:\Users\WIN 11 PRO\AppData\Local\Temp\ipykernel_12656\3315112304.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(mode_val, inplace=True)

# %%
df.drop('Happiness_Score', axis=1, inplace=True)

# %%
X = df.drop('Wellness_Score_Category', axis=1)
y = df['Wellness_Score_Category']

# %%
numerical_features = [col for col in X.select_dtypes(include=['float64', 'int64']).columns if col != 'Happiness_Score']
categorical_features = X.select_dtypes(include=['object']).columns

# %%
X_categorical_encoded = pd.get_dummies(X[categorical_features], drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_numerical_scaled = scaler.fit_transform(X[numerical_features])
X_numerical_scaled = pd.DataFrame(X_numerical_scaled, columns=numerical_features, index=X.index)

# %%
X_processed = pd.concat([X_numerical_scaled, X_categorical_encoded], axis=1)
X_processed.head()
# Out:
#         Age  Height_cm  Weight_kg       BMI  Work_Hours_Per_Week  Daily_Steps  \
# 0  1.169282   0.499741  -0.403863 -0.196416            -1.775053    -0.172406
# 1  0.385281  -1.706513  -0.911194 -1.079359             1.414460     1.311226
# 2 -0.712319   0.908306   0.385318  0.363499            -1.356756    -0.011811
# 3  1.482882   0.336315  -0.009273 -0.002599             0.316431     1.511783
# 4 -1.261120   1.316872   0.103467 -0.002599             0.002708    -1.754534
#
#    Sleep_Hours  Screen_Time_Hours  Water_Intake_Liters  \
# 0     1.141138          -0.535393             1.161674
# 1    -1.178124          -1.337276             0.839311
# 2     0.103573          -0.902923            -0.691911
# 3    -0.018493          -0.401746             1.242265
# 4    -0.323659          -1.637982             0.033405
#
#    Mental_Wellbeing_Score  ...  Meditation_Habit_Yes  Work_Life_Balance_Good  \
# 0                0.159080  ...                 False                    True
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8000, 50)
# (2000, 50)
# (8000,)
# (2000,)

# %%
from sklearn.linear_model import LogisticRegression

log_reg_model = LogisticRegression(max_iter=1000, random_state=42)
log_reg_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_pred = log_reg_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_test, y_pred))
# Out:
# 0.3615

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.38      0.50      0.43       720
#          Low       0.36      0.48      0.41       691
#       Medium       0.29      0.06      0.09       589
#
#     accuracy                           0.36      2000
#    macro avg       0.34      0.34      0.31      2000
# weighted avg       0.34      0.36      0.32      2000

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[357 325  38]
#  [315 333  43]
#  [279 277  33]]

# %%
cm = confusion_matrix(y_test, y_pred)
class_labels = log_reg_model.classes_

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='coolwarm',
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap')
plt.show()
